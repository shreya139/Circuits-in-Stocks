# %% [markdown]
# #Id- 202218061

# %% [markdown]
# There are many ratios that investors use to analyze stocks and predict their future price movements. **Here are 21 fundamental ratios along with their formulas to calculate:**
#
#
# 1.Price to Earnings Ratio (P/E Ratio) = Market Price per Share / Earnings per Share (EPS)
#
#
# 2.Price to Sales Ratio (P/S Ratio) = Market Price per Share / Revenue per Share
#
#
# 3.Price to Book Ratio (P/B Ratio) = Market Price per Share / Book Value per Share
#
#
# 4.Price to Cash Flow Ratio (P/CF Ratio) = Market Price per Share / Operating Cash Flow per Share
#
# 5.Enterprise Value-to-EBITDA Ratio (EV/EBITDA Ratio) = Enterprise Value / Earnings Before Interest, Taxes, Depreciation, and Amortization (EBITDA)
#
#
# 6.Dividend Yield = Dividend per Share / Market Price per Share
#
#
# 7.Dividend Payout Ratio = Dividends per Share / Earnings per Share
#
#
# 8.Return on Equity (ROE) = Net Income / Shareholder’s Equity
#
#
# Return on Assets (ROA) = Net Income / Total Assets
#
#
# Return on Investment (ROI) = (Net Profit / Investment) x 100
#
#
# Debt to Equity Ratio = Total Debt / Total Equity
#
#
# Current Ratio = Current Assets / Current Liabilities
#
#
# Quick Ratio = (Current Assets - Inventory) / Current Liabilities
#
#
# Debt to Asset Ratio = Total Debt / Total Assets
#
#
# Operating Margin = Operating Income / Revenue
#
#
# Gross Margin = Gross Profit / Revenue
#
#
# Net Profit Margin = Net Income / Revenue
#
#
# Earnings Per Share (EPS) = Net Income / Shares Outstanding
#
#
# Price to Free Cash Flow Ratio (P/FCF Ratio) = Market Price per Share / Free
# Cash Flow per Share
#
#
# Price to Operating Cash Flow Ratio (P/OCF Ratio) = Market Price per Share / Operating Cash Flow per Share
#
#
# Price to Earnings Growth Ratio (PEG Ratio) = P/E Ratio / EPS Growth Rate.

# %%
import numpy as np
import pandas as pd
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt

# %%
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SALASAR.NS", start="2021-04-01", end="2022-03-31",interval='1d')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2021-04-01  18.350000  18.995001  18.157499  18.610001  17.909559   819140
# 2021-04-05  18.745001  18.817499  18.267500  18.637501  17.936024   515600
# 2021-04-06  18.900000  20.299999  18.512501  19.990000  19.237617  3318480
# 2021-04-07  20.400000  20.985001  20.142500  20.655001  19.877590  2040560
# 2021-04-08  20.850000  21.342501  20.750000  21.125000  20.329899  1443620
# ...               ...        ...        ...        ...        ...      ...
# 2022-03-24  22.400000  22.510000  22.110001  22.209999  22.142900   334680
# 2022-03-25  22.485001  22.895000  22.000000  22.445000  22.377192  1183710
# 2022-03-28  22.700001  22.799999  21.750000  21.820000  21.754078   819440
# 2022-03-29  21.995001  22.100000  21.400000  21.530001  21.464956  1660480
# ...

# %% [markdown]
# #Q-4 FINANCIAL RESULTS ARE NOT RELIASED YET FOR THIS WE ARE USING DATASET PERIOD 1 APRIL 2021 TO 31ST MARCH 2022

# %%
#Financial of Salasar company
fin_sal = pd.read_csv('https://raw.githubusercontent.com/shreya139/Circuits-in-Stocks/main/DATASET_61/yearly_fin_salasar_MP.csv')

# %%
fin_sal
# Out:
#                            Salasar Techno Engineering  \
# 0                        Standalone Quarterly Results
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                    Net Sales/Income from operations
# 9                              Other Operating Income
# 10                       Total Income From Operations
# 11                                        EXPENDITURE
# 12                       Consumption of Raw Materials
# 13                           Purchase of Traded Goods
# 14                        Increase/Decrease in Stocks
# 15                                       Power & Fuel
# ...

# %% [markdown]
# #1. FINDING EPS

# %%
fin_sal.isna().sum()
# Out:
# Salasar Techno Engineering     7
# Previous Years »              12
# Unnamed: 2                    13
# Unnamed: 3                    13
# Unnamed: 4                    13
# Unnamed: 5                    14
# dtype: int64

# %%
fin_sal = fin_sal.dropna()
fin_sal.isna().sum()
fin_sal
# Out:
#                            Salasar Techno Engineering Previous Years »  \
# 8                    Net Sales/Income from operations            690.9
# 9                              Other Operating Income               --
# 10                       Total Income From Operations            690.9
# 12                       Consumption of Raw Materials            571.5
# 13                           Purchase of Traded Goods               --
# 14                        Increase/Decrease in Stocks           -22.46
# 15                                       Power & Fuel               --
# 16                                     Employees Cost            38.01
# 17                                       Depreciation              7.1
# 18                                        Excise Duty               --
# 19                        Admin. And Selling Expenses               --
# 20                                     R & D Expenses               --
# ...

# %%
df = fin_sal.reset_index()
df.head()
# Out:
#    index        Salasar Techno Engineering Previous Years » Unnamed: 2  \
# 0      8  Net Sales/Income from operations            690.9     583.31
# 1      9            Other Operating Income               --         --
# 2     10      Total Income From Operations            690.9     583.31
# 3     12      Consumption of Raw Materials            571.5         --
# 4     13          Purchase of Traded Goods               --         --
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0     525.51     654.32     477.29
# 1         --         --         --
# 2     525.51     654.32     477.29
# 3     397.58         --     347.79
# 4         --         --         --

# %%
# df = df.drop(['index'] , axis =1)
# df.head(3)

# %%
#Renaming columns 
df.rename(columns = {'Previous Years »':"mar'22" , "Unnamed: 2" : "mar'21" ,"Unnamed: 3":"mar'20","Unnamed: 4":"mar'19" , "Unnamed: 5":"mar'18" }, inplace = True)
df
# Out:
#     index                         Salasar Techno Engineering   mar'22  \
# 0       8                   Net Sales/Income from operations    690.9
# 1       9                             Other Operating Income       --
# 2      10                       Total Income From Operations    690.9
# 3      12                       Consumption of Raw Materials    571.5
# 4      13                           Purchase of Traded Goods       --
# 5      14                        Increase/Decrease in Stocks   -22.46
# 6      15                                       Power & Fuel       --
# 7      16                                     Employees Cost    38.01
# 8      17                                       Depreciation      7.1
# 9      18                                        Excise Duty       --
# 10     19                        Admin. And Selling Expenses       --
# 11     20                                     R & D Expenses       --
# ...

# %%
# df_outstanding_share = df[df['Salasar Techno Engineering'] == 'Net Profit/(Loss) For the Period	']
# df_outstanding_share
net_income = float(df.loc[26][2]) * 10**7
net_income
# Out:
# 318100000.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# For outstanding share 
facevalue = 10
outstanding_shr = (float(df.loc[27][2]) * 10**7) / facevalue
outstanding_shr
# Out:
# 28570000.0

# %% [markdown]
# #PER SHARE RATIOS
# #EPS

# %%
# Calculate earnings per share
EPS = net_income / outstanding_shr
EPS
# Out:
# 11.134056702835142

# %% [markdown]
# validated from balacesheet,MAR'22

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #VALUATION RATIO
#
# #PE RATIO

# %%
# #Normalizing data
# from sklearn import preprocessing

# # nor_PE = preprocessing.normalize([PE['PE']])
# nor_close = preprocessing.normalize([data['Close']])

# %%
market_price = data['Close']
# market_price = nor_close

# %%
# Calculate P/E ratio
PE = market_price / EPS
# print("Reliance Industries' P/E ratio is:", round(PE, 2))
PE = pd.DataFrame(PE)
PE.rename(columns = {"Close":"PE" }, inplace = True)
PE
# Out:
#                   PE
# Date
# 2021-04-01  1.671448
# 2021-04-05  1.673918
# 2021-04-06  1.795392
# 2021-04-07  1.855119
# 2021-04-08  1.897332
# ...              ...
# 2022-03-24  1.994780
# 2022-03-25  2.015887
# 2022-03-28  1.959753
# 2022-03-29  1.933707
# 2022-03-30  1.928318
#
# [247 rows x 1 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 5))
plt.plot(PE.index, PE['PE'] , label ='PE')
plt.title('Price to Earnings Ratio (P/E Ratio) for 2021-22 financial year for SALASAR STOCK')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(data.index, data['Close'] )
plt.title('Price for 2021-22 financial year for SALASAR STOCK')
plt.show()

# %%
#Finding correlation 
import scipy.stats
print("CORRELATION B/W PE AND CLOSING PRICE :",scipy.stats.pearsonr(data['Close'] , PE['PE'])[0] )    # Pearson's r
# Out:
# CORRELATION B/W PE AND CLOSING PRICE : 1.0

# %% [markdown]
# #EXTRACTING NIFTY DATA

# %%
import yfinance as yf

# Define the ticker symbol
tickerSymbol = "^NSEI"

# Get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

# Get the historical prices for this ticke
nifty_df = tickerData.history(period='1d', start='2021-4-1', end='2022-3-31')

# Print the dataframe
nifty_df
# Out:
#                                    Open          High           Low  \
# Date
# 2021-04-01 00:00:00+05:30  14798.400391  14883.200195  14692.450195
# 2021-04-05 00:00:00+05:30  14837.700195  14849.849609  14459.500000
# 2021-04-06 00:00:00+05:30  14737.000000  14779.099609  14573.900391
# 2021-04-07 00:00:00+05:30  14716.450195  14879.799805  14649.849609
# 2021-04-08 00:00:00+05:30  14875.650391  14984.150391  14821.099609
# ...                                 ...           ...           ...
# 2022-03-24 00:00:00+05:30  17094.949219  17291.750000  17091.150391
# 2022-03-25 00:00:00+05:30  17289.000000  17294.900391  17076.550781
# 2022-03-28 00:00:00+05:30  17181.849609  17235.099609  17003.900391
# 2022-03-29 00:00:00+05:30  17297.199219  17343.650391  17235.699219
# 2022-03-30 00:00:00+05:30  17468.150391  17522.500000  17387.199219
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# ...

# %%
#Finding correlation 
import scipy.stats
print("CORRELATION B/W NIFTY AND CLOSING PRICE :",scipy.stats.pearsonr(data['Close'] , nifty_df['Close'])[0] )    # Pearson's r
# Out:
# CORRELATION B/W NIFTY AND CLOSING PRICE : -0.20911021093155235

# %% [markdown]
# #CORREALATION B/W NIFTY AND RELIANCE STOCK

# %%
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
rel_data = pdr.get_data_yahoo("RELIANCE.NS", start="2021-04-01", end="2022-03-31",interval='1d')
#Finding correlation 
import scipy.stats
print("CORRELATION B/W NIFTY AND (RELIANCE)CLOSING PRICE :",scipy.stats.pearsonr(rel_data['Close'] , nifty_df['Close'])[0] )    # Pearson's r
# Out:
# [*********************100%***********************]  1 of 1 completed
# CORRELATION B/W NIFTY AND (RELIANCE)CLOSING PRICE : 0.9410343599363801

# %% [markdown]
# Nifty contains high weightage of Reliance stock that's why its correalation is high

# %% [markdown]
# #3.EXTRACTING SENSEX DATA AND COMPARING IT WITH SALASAR STOCK

# %%
import yfinance as yf

# Set the ticker symbol for Sensex
tickerSymbol = '^BSESN'

# Use the yfinance library to get the data for the given date
sensex_data = yf.download(tickerSymbol, period='1d',  start='2021-4-1', end='2022-3-31')

# Print the data
sensex_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2021-04-01  49868.531250  50092.480469  49478.531250  50029.828125
# 2021-04-05  50020.910156  50028.671875  48580.800781  49159.320312
# 2021-04-06  49441.128906  49582.261719  48936.351562  49201.390625
# 2021-04-07  49277.089844  49900.128906  49093.898438  49661.761719
# 2021-04-08  49885.261719  50118.078125  49581.609375  49746.210938
# ...                  ...           ...           ...           ...
# 2022-03-24  57190.050781  57827.988281  57138.511719  57595.679688
# 2022-03-25  57801.718750  57845.371094  57100.238281  57362.199219
# 2022-03-28  57472.718750  57638.339844  56825.089844  57593.488281
# 2022-03-29  57814.761719  58001.531250  57639.351562  57943.648438
# 2022-03-30  58362.851562  58727.781250  58176.000000  58683.988281
#
#                Adj Close  Volume
# Date
# 2021-04-01  50029.828125    8500
# ...

# %%
# remove rows where index is not the same
sala_data_new = data.drop(data.index.difference(sensex_data.index))

# %%
#Finding correlation
import scipy.stats
print("CORRELATION B/W SENSEX AND CLOSING PRICE :",scipy.stats.pearsonr(sala_data_new['Close'] , sensex_data['Close'])[0] )    # Pearson's r
# Out:
# CORRELATION B/W SENSEX AND CLOSING PRICE : -0.22317016864683528

# %% [markdown]
# #CIRCUIT BREAKER

# %%
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data_1h = pdr.get_data_yahoo("SALASAR.NS", start="2023-03-01", end="2023-04-15",interval='1h')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
def circuit_status(data_1h):
  if data['Open'] == data['Close'] == data['High'] == data['Low']:
    return 1
  else:
    return 0

# %%
import datetime
def circuit_checker(dates):
  c_data = pdr.get_data_yahoo('stockname', start=dates, end = dates + datetime.timedelta(days=1),interval='1h')
  c_data = c_data.assign(circuit=c_data.apply(circuit_status, axis=1))
  if c_data.circuit.sum():
    return 1
  else:
    return 0


def find_circuits(data):
  # adding a column which show the maximum change of price in that day.
  a=np.zeros((len(data),1)) 
  a[0] = ((data['High'][0] - data['Open'][0] )/(data['Close'][0]))*100
  for i in range(1,len(data)):
    a[i] = ((data['High'][i] - data['Close'][i-1] )/(data['Close'][i-1]))*100 
  data['high_preclose%'] = a
  # print(data)

  # adding a column to set which show if circuit is there or not
  data['possible_circuit'] = np.where(data['high_preclose%'] >= 4.5, 1, 0)
  # for date in data.query('possible_circuit == 1').index:
  for i in range(len(data)):
    if data['possible_circuit'][i] == 1:
      a[i] = circuit_checker(data.index[i] )
    else:
      a[i] = 0
  data['circuit'] = a

  # printing Dates when the circuit has happened
  print('Dates on which there is circuits')
  for date in data.query('circuit == 1').index:
    print('--->',date)
  
  plt.figure(figsize=(13,3))
  plt.plot(data['Close'])
  plt.scatter(data.query('possible_circuit == 1').index, data.query('possible_circuit == 1')['Close'], color='Red')
  plt.scatter(data.query('circuit == 1').index, data.query('circuit == 1')['Close'], color='Green')
  plt.show()

  return data

# %%
circuit_salasar = find_circuits(data_1h)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - STOCKNAME: No timezone found, symbol may be delisted
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-261c13ca7715> in <cell line: 1>()
# ----> 1 circuit_salasar = find_circuits(data_1h)
#
# <ipython-input-44-92b11e6c2275> in find_circuits(data)
#      23   for i in range(len(data)):
#      24     if data['possible_circuit'][i] == 1:
# ---> 25       a[i] = circuit_checker(data.index[i] )
#      26     else:
#      27       a[i] = 0
#
# <ipython-input-44-92b11e6c2275> in circuit_checker(dates)
#       2 def circuit_checker(dates):
#       3   c_data = pdr.get_data_yahoo('stockname', start=dates, end = dates + datetime.timedelta(days=1),interval='1h')
# ----> 4   c_data = c_data.assign(circuit=c_data.apply(circuit_status, axis=1))
# ...

# %%
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data_15m = pdr.get_data_yahoo("SALASAR.NS", start="2023-03-01", end="2023-04-15",interval='15m')

# %%
def circuit_status(data_15m):
  if data['Open'] == data['Close'] == data['High'] == data['Low']:
    return 1
  else:
    return 0

# %%
import datetime
def circuit_checker(dates):
  c_data = pdr.get_data_yahoo('SALASAR.NS', start=dates, end = dates + datetime.timedelta(days=1),interval='15m')
  c_data = c_data.assign(circuit=c_data.apply(circuit_status, axis=1))
  if c_data.circuit.sum():
    return 1
  else:
    return 0


def find_circuits(data):
  # adding a column which show the maximum change of price in that day.
  a=np.zeros((len(data),1)) 
  a[0] = ((data['High'][0] - data['Open'][0] )/(data['Close'][0]))*100
  for i in range(1,len(data)):
    a[i] = ((data['High'][i] - data['Close'][i-1] )/(data['Close'][i-1]))*100 
  data['high_preclose%'] = a
  # print(data)

  # adding a column to set which show if circuit is there or not
  data['possible_circuit'] = np.where(data['high_preclose%'] >= 4.5, 1, 0)
  # for date in data.query('possible_circuit == 1').index:
  for i in range(len(data)):
    if data['possible_circuit'][i] == 1:
      a[i] = circuit_checker(data.index[i])
    else:
      a[i] = 0
  data['circuit'] = a

  # printing Dates when the circuit has happened
  print('Dates on which there is circuits')
  for date in data.query('circuit == 1').index:
    print('--->',date)
  
  plt.figure(figsize=(13,3))
  plt.plot(data['Close'])
  plt.scatter(data.query('possible_circuit == 1').index, data.query('possible_circuit == 1')['Close'], color='Red')
  plt.scatter(data.query('circuit == 1').index, data.query('circuit == 1')['Close'], color='Green')
  plt.show()

  return data

# %%
circuit_salasar = find_circuits(data_15m)
