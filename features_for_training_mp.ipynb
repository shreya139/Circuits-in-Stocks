# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya139/Circuits-in-Stocks/blob/202218061-JATAN/features_for_training_mp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Id- 202218061

# %% [markdown]
# There are many ratios that investors use to analyze stocks and predict their future price movements. **Here are 21 fundamental ratios along with their formulas to calculate:**
#
#
# 1.Price to Earnings Ratio (P/E Ratio) = Market Price per Share / Earnings per Share (EPS)
#
#
# 2.Price to Sales Ratio (P/S Ratio) = Market Price per Share / Revenue per Share
#
#
# 3.Price to Book Ratio (P/B Ratio) = Market Price per Share / Book Value per Share
#
#
# 4.Price to Cash Flow Ratio (P/CF Ratio) = Market Price per Share / Operating Cash Flow per Share
#
# 5.Enterprise Value-to-EBITDA Ratio (EV/EBITDA Ratio) = Enterprise Value / Earnings Before Interest, Taxes, Depreciation, and Amortization (EBITDA)
#
#
# 6.Dividend Yield = Dividend per Share / Market Price per Share
#
#
# 7.Dividend Payout Ratio = Dividends per Share / Earnings per Share
#
#
# 8.Return on Equity (ROE) = Net Income / Shareholder’s Equity
#
#
# Return on Assets (ROA) = Net Income / Total Assets
#
#
# Return on Investment (ROI) = (Net Profit / Investment) x 100
#
#
# Debt to Equity Ratio = Total Debt / Total Equity
#
#
# Current Ratio = Current Assets / Current Liabilities
#
#
# Quick Ratio = (Current Assets - Inventory) / Current Liabilities
#
#
# Debt to Asset Ratio = Total Debt / Total Assets
#
#
# Operating Margin = Operating Income / Revenue
#
#
# Gross Margin = Gross Profit / Revenue
#
#
# Net Profit Margin = Net Income / Revenue
#
#
# Earnings Per Share (EPS) = Net Income / Shares Outstanding
#
#
# Price to Free Cash Flow Ratio (P/FCF Ratio) = Market Price per Share / Free
# Cash Flow per Share
#
#
# Price to Operating Cash Flow Ratio (P/OCF Ratio) = Market Price per Share / Operating Cash Flow per Share
#
#
# Price to Earnings Growth Ratio (PEG Ratio) = P/E Ratio / EPS Growth Rate.

# %%
import numpy as np
import pandas as pd
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as pdr

# %%
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SALASAR.NS", start="2022-01-01", end="2022-03-31",interval='1d')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-01-03  24.030001  24.190001  23.510000  23.709999  23.638369    387170
# 2022-01-04  23.955000  25.495001  23.500000  25.290001  25.213596   1495830
# 2022-01-05  25.500000  26.200001  24.764999  25.975000  25.896526   1306810
# 2022-01-06  26.180000  26.180000  25.205000  25.334999  25.258459    529350
# 2022-01-07  25.590000  25.590000  25.000000  25.135000  25.059065    478210
# 2022-01-10  25.100000  26.000000  25.000000  25.840000  25.761934   2427170
# 2022-01-11  25.840000  26.670000  25.215000  26.370001  26.290335   2040010
# 2022-01-12  26.490000  27.225000  25.230000  26.735001  26.654230   3116460
# 2022-01-13  27.370001  27.370001  25.930000  26.375000  26.295319   1384660
# 2022-01-14  26.200001  26.299999  25.430000  25.830000  25.751965    937430
# ...

# %% [markdown]
# #Q-4 FINANCIAL RESULTS ARE NOT RELIASED YET FOR THIS WE ARE USING DATASET PERIOD 1ST JAN 2022 TO 31ST

# %%
#Financial of Salasar company
fin_sal = pd.read_csv('https://raw.githubusercontent.com/shreya139/Circuits-in-Stocks/data/Financial_salasar_MP%20-%20Sheet1.csv')

# %%
fin_sal
# Out:
#                            Salasar Techno Engineering  dec'22  sep'22 june'22  \
# 6                    Net Sales/Income from operations   240.8  255.82  209.35
# 7                              Other Operating Income      --      --      --
# 8                        Total Income From Operations   240.8  255.82  209.35
# 10                       Consumption of Raw Materials   211.3      --      --
# 11                           Purchase of Traded Goods      --      --      --
# 12                        Increase/Decrease in Stocks  -19.46   19.66  -14.27
# 13                                       Power & Fuel      --      --      --
# 14                                     Employees Cost   11.22   12.33      10
# 15                                       Depreciation    1.99    1.92    1.87
# 16                                        Excise Duty      --      --      --
# 17                        Admin. And Selling Expenses      --      --      --
# ...

# %% [markdown]
# #1. FINDING EPS

# %%
fin_sal.isna().sum()
# Out:
# Salasar Techno Engineering     5
# Previous Years »              11
# Unnamed: 2                    12
# Unnamed: 3                    12
# Unnamed: 4                    12
# dtype: int64

# %%
fin_sal = fin_sal.dropna()
fin_sal.isna().sum()
fin_sal.head()
# Out:
#           Salasar Techno Engineering Previous Years » Unnamed: 2 Unnamed: 3  \
# 6   Net Sales/Income from operations            240.8     255.82     209.35
# 7             Other Operating Income               --         --         --
# 8       Total Income From Operations            240.8     255.82     209.35
# 10      Consumption of Raw Materials            211.3         --         --
# 11          Purchase of Traded Goods               --         --         --
#
#    Unnamed: 4
# 6      201.31
# 7          --
# 8      201.31
# 10     160.21
# 11         --

# %%
df = fin_sal.reset_index()
df.head()
# Out:
#    index        Salasar Techno Engineering Previous Years » Unnamed: 2  \
# 0      6  Net Sales/Income from operations            240.8     255.82
# 1      7            Other Operating Income               --         --
# 2      8      Total Income From Operations            240.8     255.82
# 3     10      Consumption of Raw Materials            211.3         --
# 4     11          Purchase of Traded Goods               --         --
#
#   Unnamed: 3 Unnamed: 4
# 0     209.35     201.31
# 1         --         --
# 2     209.35     201.31
# 3         --     160.21
# 4         --         --

# %%
# df = df.drop(['index'] , axis =1)
# df.head(3)

# %%
#Renaming columns 
df.rename(columns = {'Previous Years »':"dec'22" , "Unnamed: 2" : "sep'22" ,"Unnamed: 3":"june'22","Unnamed: 4":"mar'22"}, inplace = True)
df.head(1)
# Out:
#          Salasar Techno Engineering dec'22  sep'22 june'22  mar'22
# 0  Net Sales/Income from operations  240.8  255.82  209.35  201.31

# %%
df_outstanding_share = df[df['Salasar Techno Engineering'] == 'Standalone share']
df_outstanding_share
# Out:
# Empty DataFrame
# Columns: [Salasar Techno Engineering, dec'22, sep'22, june'22, mar'22]
# Index: []

# %%
#EPS for 1 jan 2022 to 31st march 2022
